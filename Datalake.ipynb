# %%
# !pip install plotly seaborn matplotlib networkx scikit-learn
# Out:
# Collecting plotly
#   Using cached plotly-6.7.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: matplotlib in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (3.10.9)
# Collecting networkx
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Using cached narwhals-2.21.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: packaging in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from plotly) (26.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=8 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tzdata in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\zenbook\onedrive\documents\data mining\ekatarimalkernel\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached plotly-6.7.0-py3-none-any.whl (9.9 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.1 MB 5.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.1 MB 3.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.9 MB/s eta 0:00:00
# Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached narwhals-2.21.0-py3-none-any.whl (451 kB)
# Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, networkx, narwhals, joblib, scikit-learn, plotly, seaborn
# Successfully installed joblib-1.5.3 narwhals-2.21.0 networkx-3.6.1 plotly-6.7.0 scikit-learn-1.8.0 scipy-1.17.1 seaborn-0.13.2 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: C:\Users\Zenbook\OneDrive\Documents\Data Mining\EkataRimalKernel\Scripts\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import json
import os
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

print("[SYSTEM] Environment ready. All libraries imported.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       2 import numpy as np
#       3 import json
#       4 import os
#       5 import plotly.express as px
# ----> 6 import seaborn as sns
#       7 import matplotlib.pyplot as plt
#       8 import networkx as nx
#       9 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in e:\ekatarimalkernel\lib\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in e:\ekatarimalkernel\lib\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in e:\ekatarimalkernel\lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in e:\ekatarimalkernel\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\ekatarimalkernel\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\ekatarimalkernel\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\ekatarimalkernel\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in e:\ekatarimalkernel\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in e:\ekatarimalkernel\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in e:\ekatarimalkernel\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\ekatarimalkernel\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in e:\ekatarimalkernel\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in e:\ekatarimalkernel\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import json
import os
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

print("[SYSTEM] Environment ready. All libraries imported.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       4 import os
#       5 import plotly.express as px
#       6 import seaborn as sns
#       7 import matplotlib.pyplot as plt
# ----> 8 import networkx as nx
#       9 from sklearn.preprocessing import StandardScaler
#      10 from sklearn.decomposition import PCA
#      11
#
# ModuleNotFoundError: No module named 'networkx'

# %%
# %pip install networkx
# Out:
# Collecting networkx
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: networkx
# Successfully installed networkx-3.6.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import json
import os
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

print("[SYSTEM] Environment ready. All libraries imported.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       5 import plotly.express as px
#       6 import seaborn as sns
#       7 import matplotlib.pyplot as plt
#       8 import networkx as nx
# ----> 9 from sklearn.preprocessing import StandardScaler
#      10 from sklearn.decomposition import PCA
#      11
#      12 import warnings
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import pandas as pd
import numpy as np
import json
import os
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

print("[SYSTEM] Environment ready. All libraries imported.")
# Out:
# [SYSTEM] Environment ready. All libraries imported.

# %%
os.makedirs('data_lake', exist_ok=True)
np.random.seed(42)
num_rows = 5000

products = ["Laptop", "Mouse", "Phone", "TV", "Cables", "Monitor", "Keyboard"]
stores = ["London-01", "Paris-05", "NYC-02", "Tokyo-04", "Berlin-03"]

# 1. SOURCE A: Nested JSON (e.g., Web API) with Noise
json_data = []
for i in range(num_rows):
    txn_id = f"JSON_{i:05d}"
    
    price = np.random.uniform(50, 1500)
    if np.random.rand() < 0.05:
        price = "REFUNDED" if np.random.rand() > 0.5 else "$PENDING" # Type mixup
        
    json_data.append({
        "transaction_id": txn_id,
        "meta_info": {
            "timestamp": (pd.to_datetime('2023-01-01') + pd.Timedelta(days=np.random.randint(0, 180))).strftime('%Y-%m-%d'),
            "store_id": np.random.choice(stores + [None, "UNKNOWN"])
        },
        "basket": [{"product": np.random.choice(products), "quantity": np.random.randint(1, 5), "unit_price": price}]
    })

json_data = json_data + json_data[:100] # Inject duplicates
with open('data_lake/source_a_transactions.json', 'w') as f:
    json.dump(json_data, f)

# 2. SOURCE B: Flat CSV (e.g., POS system) with Noise
csv_rows = []
for i in range(num_rows):
    txn_id = f"CSV_{i:05d}"
    qty = np.random.randint(1, 10)
    if np.random.rand() < 0.05:
        qty = "QTY_ERR" if np.random.rand() > 0.5 else None # Missing Values & Type mixup
        
    csv_rows.append({
        "LOG_ID": txn_id,
        "EVENT_TIME": (pd.to_datetime('2023-07-01') + pd.Timedelta(days=np.random.randint(0, 180))).strftime('%Y-%m-%d'),
        "LOCATION": np.random.choice(stores),
        "ITEM": np.random.choice(products),
        "UNITS": qty,
        "PRICE_PER_UNIT": np.random.uniform(-500, 2000) # Negative price outliers
    })

pd.DataFrame(csv_rows).to_csv('data_lake/source_b_logs.csv', index=False)
print("[SYSTEM] Data Lake initialized with messy JSON and CSV files.")
# Out:
# [SYSTEM] Data Lake initialized with messy JSON and CSV files.

# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in e:\ekatarimalkernel\lib\site-packages (from scikit-learn) (2.4.4)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
